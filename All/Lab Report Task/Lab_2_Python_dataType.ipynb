# %% [markdown]
# <div align="center">
#
# # **University of Engineering And Technology Peshawar**
#
# ## *Jalozai Campus*
#
# </div>

# %% [markdown]
# _____

# %% [markdown]
# <div align="center">
#
# ---
#
# # **COURSE TITLE**
#
# ## Introduction to AI Programming
#
# ---
#
# </div>

# %% [markdown]
# <div style="
#     max-width:700px;
#     margin:40px auto;
#     padding:25px 30px;
#     border:2px solid #2c3e50;
#     border-radius:12px;
#     background:#ffffff;
#     box-shadow:0 5px 12px rgba(0,0,0,0.15);
#     font-family:'Times New Roman', serif;
# ">
#
# <h3 style="color:#34495e; border-bottom:2px solid #bdc3c7; padding-bottom:6px;">
# 📋 Lab Information
# </h3>
#
# <ul style="list-style:none; padding-left:0;">
#     <li><strong>Lab No.</strong>: <span style="color:#e74c3c; font-weight:bold;">2</span></li>
#     <li><strong>Lab Title</strong>: <span style="color:#2980b9; font-weight:bold;">Python Basic Datatype</span></li>
# </ul>
#
# <hr style="border:none; border-top:2px dashed #ccc; margin:20px 0;">
#
# <h3 style="color:#34495e; border-bottom:2px solid #bdc3c7; padding-bottom:6px;">
# 🙋‍♂️ Submitted By
# </h3>
#
# <ul style="list-style:none; padding-left:0;">
#     <li><strong>Name</strong>: <span style="color:#2980b9; font-weight:bold;">M. Sheth Mughal</span></li>
#     <li><strong>Roll No.</strong>: <span style="color:#e74c3c; font-weight:bold;">24JZELE0558</span></li>
#     <li><strong>Section</strong>: <span style="color:#16a085; font-weight:bold;">A</span></li>
# </ul>
#
# </div>

# %% [markdown]
# ___

# %% [markdown]
# # Lab Report Tasks:

# %% [markdown]
# ___

# %% [markdown]
# ### Find Total Impedance
# **i**. Add the three impedances.
#
# **ii**. Print `real part` (resistive) and `imaginary part` (reactive).
#
# **iii**. Print `magnitude` and `phase angle` (use abs() and cmath.phase()).

# %% [markdown]
# ___

# %% [markdown]
# ### Q.1) Add the three impedances.

# %%
Z1 = complex(3, 4)  # Z1 = 3 + 4j
Z2 = complex(2, -3)  # Z2 = 2 - 3j
Z3 = complex(1, 2)  # Z3 = 1 + 2j

# 1. Add the three impedances
Z_total = Z1 + Z2 + Z3
print(f"TOTAL_IMPEDNCES: {Z_total}")
# Out:
# TOTAL_IMPEDNCES: (6+3j)

# %% [markdown]
# ___

# %% [markdown]
# ### Q.2) Print `real part` (resistive) and `imaginary part` (reactive).

# %%
print("Real part (Resistive):", Z_total.real)
print("Imaginary part (Reactive):", Z_total.imag)
# Out:
# Real part (Resistive): 6.0
# Imaginary part (Reactive): 3.0

# %% [markdown]
# ___

# %% [markdown]
# ### Q.3) Print `magnitude` and `phase angle` (use abs() and cmath.phase()).

# %%
# for pahse angle  we use import cmath
import cmath

# %%
magnitude = abs(Z_total)
phase_angle = cmath.phase(Z_total)

print("Magnitude of Total Impedance:", magnitude)
print("Phase Angle of Total Impedance:", phase_angle, "radians")
# Out:
# Magnitude of Total Impedance: 6.708203932499369
# Phase Angle of Total Impedance: 0.4636476090008061 radians

# %% [markdown]
# ___
