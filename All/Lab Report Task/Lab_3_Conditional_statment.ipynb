# %% [markdown]
# <div align="center">
#
# # **University of Engineering And Technology Peshawar**
#
# ## *Jalozai Campus*
#
# </div>

# %% [markdown]
# _________

# %% [markdown]
# <div align="center">
#
# ---
#
# # **COURSE TITLE**
#
# ## Introduction to AI Programming
#
# ---
#
# </div>

# %% [markdown]
# <div style="
#     max-width:700px;
#     margin:40px auto;
#     padding:25px 30px;
#     border:2px solid #2c3e50;
#     border-radius:12px;
#     background:#ffffff;
#     box-shadow:0 5px 12px rgba(0,0,0,0.15);
#     font-family:'Times New Roman', serif;
# ">
#
# <h3 style="color:#34495e; border-bottom:2px solid #bdc3c7; padding-bottom:6px;">
# 📋 Lab Information
# </h3>
#
# <ul style="list-style:none; padding-left:0;">
#     <li><strong>Lab No.</strong>: <span style="color:#e74c3c; font-weight:bold;">3</span></li>
#     <li><strong>Lab Title</strong>: <span style="color:#2980b9; font-weight:bold;">conditional statements</span></li>
# </ul>
#
# <hr style="border:none; border-top:2px dashed #ccc; margin:20px 0;">
#
# <h3 style="color:#34495e; border-bottom:2px solid #bdc3c7; padding-bottom:6px;">
# 🙋‍♂️ Submitted By
# </h3>
#
# <ul style="list-style:none; padding-left:0;">
#     <li><strong>Name</strong>: <span style="color:#2980b9; font-weight:bold;">M. Sheth Mughal</span></li>
#     <li><strong>Roll No.</strong>: <span style="color:#e74c3c; font-weight:bold;">24JZELE0558</span></li>
#     <li><strong>Section</strong>: <span style="color:#16a085; font-weight:bold;">A</span></li>
# </ul>
#
# </div>

# %% [markdown]
# ____

# %% [markdown]
# # Lab Report Tasks:

# %% [markdown]
# ____

# %% [markdown]
# A resistor with zero value creates a short circuit, which can damage the circuit. Students need to test the resistance before use.
# Check if the resistance value is zero. If yes, print "Short Circuit", else print "Safe".
# Store resistance in a variable, use if-else.

# %%
# Resistor=float(input('Resistor')) --> this is for input 
Resistor=9
if Resistor==0:
    print("Short Circuit")
else:
    print("safe")
# Out:
# safe
