# %% [markdown]
# ### Scripts in Python
# In Python, a script is simply a file containing Python code that is meant to be run directly to perform a specific task.

# %% [markdown]
# In computing, the term script refers to a text file containing a logical sequence of orders that you can run to accomplish a specific task. These orders are typically expressed in a scripting language, which is a programming language that allows you to manipulate, customize, and automate tasks.

# %% [markdown]
# Python is an interpreted language.
#
# Python code is read and executed line-by-line by an interpreter at runtime, instead of being fully compiled into machine code beforehand.

# %% [markdown]
#  A file containing executable Python code is called a script—or an entry-point script in more complex applications—which is a common term for a top-level program. On the other hand, a file containing Python code that’s designed to be imported and used from another Python file is called a module.

# %% [markdown]
# the main difference between a module and a script is that modules store importable code while scripts hold executable code.

# %% [markdown]
# Importable code is code that defines something but doesn’t perform a specific action. Some examples include function and class definitions.

# %% [markdown]
# Executable code is code that performs specific actions. Some examples include function calls, loops, and conditionals.

# %% [markdown]
# #### How to Run Python Scripts From the Command Line
# to run the scripts in commond line enter the path in commond line and .py file.

# %% [markdown]
# ![image.png](attachment:image.png)
# the script is running in CMD

# %% [markdown]
# #### Using the python Command
# using the pyton commond enter the following into the interactive shell.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In this command, the > symbol tells the shell to redirect the output of your command to the output.txt file, rather than to the standard system output, your screen. This process is commonly known as redirection,
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Using the Script’s Filename Directly
# On Windows, you can also run Python scripts by simply entering the name of the file containing the executable code at the command line

# %% [markdown]
# when we enter(.\filename.py) and then enter the goes directly to the file and open it

# %% [markdown]
# #### Running Modules With the -m Option

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In this example, you run the hello.py file as a module. This is possible because Python automatically adds the current directory to its sys.path list. Note that the module-name argument needs to be the name of a module object, not a file name. In other words, you don’t include the .py suffix

# %% [markdown]
# #### Running Python Code Interactively

# %% [markdown]
# ![image.png](attachment:image.png)
# he standard primary prompt for the interactive mode consists of three right angle brackets, >>>. So, as soon as you see these characters.
#
# The standard Read Evaluate Print Loop(REPL) also has a secondary prompt that consists of three periods (...). This prompt appears when you add indented lines to a compound statement, such as conditionals, function and class definitions, and loops.

# %% [markdown]
# Reading your input, which consists of Python code as expressions and statements.
#
# Evaluating your Python code, which generates a result or causes side effects.
#
# Printing any output so that you can check your code’s results and get immediate feedback.
#
# Looping back to step one to continue the interaction.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To leave interactive mode and jump back to the system shell, you can use one of the following options:
#
# Executing the built-in quit() or exit() functions
# Pressing the Ctrl+Z and Enter key combination on Windows, or the Ctrl+D combination on Unix systems, such as Linux and macOS

# %% [markdown]
# #### How to Run Scripts From Python Code

# %% [markdown]
# taking advantage of import statement
# ![image.png](attachment:image.png)

# %% [markdown]
# when you use import hello then it run first time and then when you impor hello call it do nothing because python gives extra steps to optimize overall performance.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Using the importlib Standard-Library Module

# %% [markdown]
# The importlib module give us the directory of the file.
# ![image.png](attachment:image.png)

# %% [markdown]
# You already know that once you’ve imported a module for the first time, you won’t be able to import it again using another import statement. If you want to reload the module and run it once again, then you can use the reload() function, which forces the interpreter to import the module again:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Leveraging the Power of the Built-in exec() Function
# The exec() function provides an alternative way to run your scripts from inside your code:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### How to Run Python Scripts on IDEs and Code Editors
