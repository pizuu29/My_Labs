# %% [markdown]
# ### Reading and  Writing Files

# %%
import os
os.path.join("usr","bin","spam")
# Out:
# 'usr\\bin\\spam'

# %%
my_files= ['accounts.txt', 'details.csv', 'invite.docx']
for file_name in my_files:
    print(os.path.join("c:\\user\\aizaz",file_name))
# Out:
# c:\user\aizaz\accounts.txt
# c:\user\aizaz\details.csv
# c:\user\aizaz\invite.docx

# %%
os.getcwd()
# Every program that runs on your computer has a current working directory,or cwd
# Out:
# 'd:\\pyhton and ML 25\\python 25'

# %% [markdown]
# #### Absolute vs. Relative Paths
# There are two ways to specify a file path.
#
# Absolute path which always begins with begins with the root folder
#
# A relative path which is relative to the program's current working directory.

# %% [markdown]
# There are also the dot (.) and dot-dot (..) folders. These are not real
# folders but special names that can be used in a path. A single period (“dot”)
# for a folder name is shorthand for “this directory.” Two periods (“dot-dot”)
# means “the parent folder.”

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
os.makedirs('C:\\Aizaz\\Python and ML\\Pyton 25')
# This will create the new folder of Aizaz.

# %%
import os
os.path.abspath(".")
os.path.abspath(".\\read_wrie")
# Out:
# 'd:\\pyhton and ML 25\\python 25\\read_wrie'

# %%
path = 'C:\\Windows\\System32\\calc.exe'
print(os.path.dirname(path))# and this will get you a dir name c:\\windows\\system32
print(os.path.basename(path))# this will get you a base name calc.exe
# Out:
# C:\Windows\System32
# calc.exe

# %% [markdown]
# If you need a path’s dir name and base name together, you can just call
# os.path.split() to get a tuple value with these two strings

# %%
path = 'C:\\Windows\\System32\\calc.exe'
print(os.path.split(path))
print(path.split(os.path.sep))
# Out:
# ('C:\\Windows\\System32', 'calc.exe')
# ['C:', 'Windows', 'System32', 'calc.exe']

# %% [markdown]
# #### Finding File Sizes and Folder Contents
# •	Calling os.path.getsize(path) will return the size in bytes of the file in
# the path argument.
#
#  •	Calling os.listdir(path) will return a list of filename strings for each file
# in the path argument. (Note that this function is in the os module, not
# os.path.)

# %%
os.path.getsize('C:\\Windows\\System32\\calc.exe')
# Out:
# 45056

# %% [markdown]
# ####  Checking Path Validity
# •	Calling os.path.exists(path) will return True if the file or folder referred to in the argument exists and will return False if it does not exist.
#
#  •	Calling os.path.isfile(path) will return True if the path argument exists and is a file and will return False otherwise.
#
#  •	Calling os.path.isdir(path) will return True if the path argument exists and is a folder and will return False otherwise.

# %%
print(os.path.exists('C:\\Windows'))
print(os.path.exists("C:\\self_made_file"))
# Out:
# True
# False

# %%
os.path.isdir('C:\\Windows\\System32')
# Out:
# True

# %%
os.path.exists("D:\\")
# Out:
# True

# %%
with open(r"C:/Users/TOSHIBA/New_folder/ab.js", "r") as file:
    content = file.read()
    print(content)
# Out:
# // Smooth Scroll
# document.querySelectorAll('a[href^="#"]').forEach(anchor => {
#     anchor.addEventListener('click', function (e) {
#       e.preventDefault();
#
#       document.querySelector(this.getAttribute('href')).scrollIntoView({
#         behavior: 'smooth'
#       });
#     });
#   });
#
#   // Alert for "Join Now" Button (you can add this button in the HTML)
#   const joinButton = document.querySelector('.join-btn');
#   if (joinButton) {
#     joinButton.addEventListener('click', () => {
#       alert('Thank you for your interest! A team member will contact you shortly.');
#     });
#   }

# %%
khan=open(r"C:\Users\TOSHIBA\New_folder\khan.txt")

# %%
print(khan)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\TOSHIBA\\New_folder\\khan.txt' mode='r' encoding='UTF-8'>

# %%
with open(r"C:\Users\TOSHIBA\New_folder\khan.txt", "r") as khan_file:
    content = khan_file.read()
    print(content)
# Out:
# Aizaz ali

# %%
with open(r"C:\Users\TOSHIBA\New_folder\khan.txt", "r") as khan_file:
    content = khan_file.read()
    print(content)
# Out:
# My Name is Aizaz Ali
# I am from Buner Chagharzai
# I am study in University of Engineering and Technology Peshawar Jalozai Campus
# Now a day I am in Peshawar main campus

# %%
import shelve
shelfFile = shelve.open('mydata')
cats = ['Zophie', 'Pooka', 'Simon']
shelfFile['cats'] = cats
shelfFile.close()

# %%
baconFile = open('bacon.txt', 'w')   
baconFile.write('Hello world!\n')

baconFile.close()
baconFile = open('bacon.txt', 'a') 
baconFile.write('Bacon is not a vegetable.')

baconFile.close()
baconFile = open('bacon.txt')
content = baconFile.read()
baconFile.close()
print(content)
# Out:
# Hello world!
# Bacon is not a vegetable.

# %% [markdown]
# First, we open bacon.txt in write mode. Since there isn’t a bacon.txt yet,
# Python creates one. Calling write() on the opened file and passing write()
# the string argument 'Hello world! /n' writes the string to the file and
# returns the number of characters written, including the newline. Then
# we close the file.

# %%
import pprint
cats = [{'name': 'Zophie', 'desc': 'chubby'}, {'name': 'Pooka', 'desc': 'fluffy'}]
pprint.pformat(cats)
# Out:
# 83
